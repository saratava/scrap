# %%
import pandas as pd
import numpy as np
from google_play_scraper import Sort, reviews_all
from pandas_profiling import ProfileReport as pr

br_reviews = reviews_all(
    'com.amazon.dee.app',
    lang='pt',  # defaults to 'en'
    sleep_milliseconds=0,  # defaults to 0
    country='br',  # defaults to 'us'
    sort=Sort.MOST_RELEVANT,  # defaults to Sort.MOST_RELEVANT
)

df_reviews = pd.DataFrame(np.array(br_reviews), columns=['review'])

df_completa = df_reviews.join(pd.DataFrame(df_reviews.pop('review').tolist()))

df_final = df_completa.drop(columns=['reviewId','userName','userImage'])

filtro_positiva = df_final['score'] >= 4
df_positiva = df_final[filtro_positiva]

filtro_neutra = df_final['score'] == 3
df_neutra = df_final[filtro_neutra]

filtro_negativa = df_final['score'] < 3
df_negativa = df_final[filtro_negativa]

profile = pr(df_final, title='Report Geral Reviews Alexa', html={'style':{'full_width':True}})

profile.to_notebook_iframe()

profile.to_file(output_file="/home/sarat/Área\ de\ Trabalho/scraping-python-google-play-scraper/Report_Scraping_Alexa.html")
# Out:
# Summarize dataset:  74%|███████▎  | 14/19 [00:00<00:00, 14.01it/s, Get dataframe statistics]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     302         try:
# --> 303             return func(*args, **kwargs)
#     304         except TypeError as ex:
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/pandas/table_pandas.py in pandas_get_table_stats(config, df, variable_stats)
#      24
# ---> 25     memory_size = df.memory_usage(deep=config.memory_deep).sum()
#      26     record_size = float(memory_size) / n if n > 0 else 0
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in memory_usage(self, index, deep)
#    2669         if index:
# -> 2670             result = Series(self.index.memory_usage(deep=deep), index=["Index"]).append(
#    2671                 result
#
# /usr/lib/python3/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     313             else:
# --> 314                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     315
#
# /usr/lib/python3/dist-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#
# /usr/lib/python3/dist-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1240
# -> 1241         subarr = np.empty(length, dtype=dtype)
#    1242         subarr.fill(value)
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
#
# The above exception was the direct cause of the following exception:
#
# DispatchError                             Traceback (most recent call last)
# /tmp/ipykernel_26557/2665394013.py in <module>
#      29 profile = pr(df_final, title='Report Geral Reviews Alexa', html={'style':{'full_width':True}})
#      30
# ---> 31 profile.to_notebook_iframe()
#      32
#      33 profile.to_file(output_file="/home/sarat/Área\ de\ Trabalho/scraping-python-google-play-scraper/Report_Scraping_Alexa.html")
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_notebook_iframe(self)
#     396         with warnings.catch_warnings():
#     397             warnings.simplefilter("ignore")
# --> 398             display(get_notebook_iframe(self.config, self))
#     399
#     400     def to_widgets(self) -> None:
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/notebook.py in get_notebook_iframe(config, profile)
#      73         output = get_notebook_iframe_src(config, profile)
#      74     elif attribute == IframeAttribute.srcdoc:
# ---> 75         output = get_notebook_iframe_srcdoc(config, profile)
#      76     else:
#      77         raise ValueError(
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/report/presentation/flavours/widget/notebook.py in get_notebook_iframe_srcdoc(config, profile)
#      27     width = config.notebook.iframe.width
#      28     height = config.notebook.iframe.height
# ---> 29     src = html.escape(profile.to_html())
#      30
#      31     iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_html(self)
#     366
#     367         """
# --> 368         return self.html
#     369
#     370     def to_json(self) -> str:
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in html(self)
#     183     def html(self) -> str:
#     184         if self._html is None:
# --> 185             self._html = self._render_html()
#     186         return self._html
#     187
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in _render_html(self)
#     285         from pandas_profiling.report.presentation.flavours import HTMLReport
#     286
# --> 287         report = self.report
#     288
#     289         with tqdm(
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in report(self)
#     177     def report(self) -> Root:
#     178         if self._report is None:
# --> 179             self._report = get_report_structure(self.config, self.description_set)
#     180         return self._report
#     181
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/profile_report.py in description_set(self)
#     159     def description_set(self) -> Dict[str, Any]:
#     160         if self._description_set is None:
# --> 161             self._description_set = describe_df(
#     162                 self.config,
#     163                 self.df,
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/model/describe.py in describe(config, df, summarizer, typeset, sample)
#     118
#     119         # Table statistics
# --> 120         table_stats = progress(get_table_stats, pbar, "Get dataframe statistics")(
#     121             config, df, series_description
#     122         )
#
# ~/.local/lib/python3.8/site-packages/pandas_profiling/utils/progress_bar.py in inner(*args, **kwargs)
#       9     def inner(*args, **kwargs) -> Any:
#      10         bar.set_postfix_str(message)
# ---> 11         ret = fn(*args, **kwargs)
#      12         bar.update()
#      13         return ret
#
# ~/.local/lib/python3.8/site-packages/multimethod/__init__.py in __call__(self, *args, **kwargs)
#     303             return func(*args, **kwargs)
#     304         except TypeError as ex:
# --> 305             raise DispatchError(f"Function {func.__code__}") from ex
#     306
#     307     def evaluate(self):
#
# DispatchError: Function <code object pandas_get_table_stats at 0x7f98884a3030, file "/home/sarat/.local/lib/python3.8/site-packages/pandas_profiling/model/pandas/table_pandas.py", line 9>
